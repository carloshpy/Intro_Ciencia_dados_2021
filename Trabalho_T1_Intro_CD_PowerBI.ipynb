# %% [markdown]
# <a href="https://colab.research.google.com/github/carloshpy/Intro_Ciencia_dados_2021/blob/main/Trabalho_T1_Intro_CD_PowerBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Trabalho T1 Intro a Ciencia de Dados
# Carlos Henrique Polo Yoshiga RA 21.84427-5
#
# João de Oliveira Ruiz RA 21.84400-3

# %% [markdown]
# ![Relacao_bases_OLIST.png](data:image/png;base64,...)

# %% [markdown]
# Notebook feito com base na aba Metodo Pagamento do Power BI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Carregamento de arquivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path_dir = '/content/drive/MyDrive/Colab Notebooks/Datasets/Introducao a CD/e-commerce'

df_customers = pd.read_csv( path_dir + '/olist_customers_dataset.csv')
df_geo = pd.read_csv(path_dir + '/olist_geolocation_dataset.csv', encoding='utf8')
df_order_items = pd.read_csv(path_dir + '/olist_order_items_dataset.csv')
df_order_pay = pd.read_csv(path_dir + '/olist_order_payments_dataset.csv')
df_reviews = pd.read_csv(path_dir + '/olist_order_reviews_dataset.csv')
df_order = pd.read_csv(path_dir + '/olist_orders_dataset.csv')
df_products = pd.read_csv(path_dir + '/olist_products_dataset.csv')
df_sellers = pd.read_csv(path_dir + '/olist_sellers_dataset.csv')

# %%
df_customers.head(3)
# Out:
#                         customer_id  ... customer_state
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# 1  18955e83d337fd6b2def6b18a428ac77  ...             SP
# 2  4e7b3e00288586ebd08712fdd0374a03  ...             SP
#
# [3 rows x 5 columns]

# %%
df_geo.head(3)
# Out:
#    geolocation_zip_code_prefix  ...  geolocation_state
# 0                         1037  ...                 SP
# 1                         1046  ...                 SP
# 2                         1046  ...                 SP
#
# [3 rows x 5 columns]

# %%
df_order.head(3)
# Out:
#                            order_id  ... order_estimated_delivery_date
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...           2017-10-18 00:00:00
# 1  53cdb2fc8bc7dce0b6741e2150273451  ...           2018-08-13 00:00:00
# 2  47770eb9100c2d0c44946d9cf07ec65d  ...           2018-09-04 00:00:00
#
# [3 rows x 8 columns]

# %%
df_order_pay.head(3)
# Out:
#                            order_id  ...  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17  ...          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0  ...          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  ...          65.71
#
# [3 rows x 5 columns]

# %%
df_order_items.head(3)
# Out:
#                            order_id  order_item_id  ...  price freight_value
# 0  00010242fe8c5a6d1ba2dd792cb16214              1  ...   58.9         13.29
# 1  00018f77f2f0320c557190d7a144bdd3              1  ...  239.9         19.93
# 2  000229ec398224ef6ca0657da4fc703e              1  ...  199.0         17.87
#
# [3 rows x 7 columns]

# %%
df_products.head(3)
# Out:
#                          product_id  ... product_width_cm
# 0  1e9e8ef04dbcff4541ed26657ea517e5  ...             14.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f  ...             20.0
# 2  96bd76ec8810374ed1b65e291975717f  ...             15.0
#
# [3 rows x 9 columns]

# %%
df_sellers.head(3)
# Out:
#                           seller_id  ...  seller_state
# 0  3442f8959a84dea7ee197c632cb2df15  ...            SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2  ...            SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d  ...            RJ
#
# [3 rows x 4 columns]

# %%
df_reviews.head(3)
# Out:
#                           review_id  ... review_answer_timestamp
# 0  7bc2406110b926393aa56f80a40eba40  ...     2018-01-18 21:46:59
# 1  80e641a11e56f04c1ad469d5645fdfde  ...     2018-03-11 03:05:13
# 2  228ce5500dc1d8e020d8d1322874b6f0  ...     2018-02-18 14:36:24
#
# [3 rows x 7 columns]

# %% [markdown]
# #Graficos feitos no Power BI feitos em Python

# %%
df_order_pay.head()
# Out:
#                            order_id  ...  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17  ...          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0  ...          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  ...          65.71
# 3  ba78997921bbcdc1373bb41e913ab953  ...         107.78
# 4  42fdf880ba16b47b59251dd489d4441a  ...         128.45
#
# [5 rows x 5 columns]

# %%
df_order_pay.payment_type.value_counts()
# Out:
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: payment_type, dtype: int64

# %%
df_order_pay[df_order_pay.payment_value>0].groupby('payment_type').payment_value.mean().sort_values(ascending= False).plot(kind = "bar")

# %%
df_order_pay[df_order_pay.payment_value>0].groupby('payment_type').order_id.nunique().sort_values(ascending= False).plot(kind = "bar")

# %%
df_order_pay[df_order_pay.payment_installments>0].groupby('payment_installments').payment_value.mean().sort_values(ascending= False).plot(kind = "bar")

# %% [markdown]
# #5.3 Conclusão

# %% [markdown]
# Mesmo fazendo um grupo de gráficos simples, é notável que em termos de exibição de dados, o Power BI é mais rápido e eficiente na hora de mostrar dados. Em alguns poucos cliques fizemos os mesmos gráficos que levamos um tempo pensando em fórmulas e consultando bibliotecas.
#
# Agora para processamento de dados e cálculos mais complexos, é mais eficiente o uso do Python e Pandas.
